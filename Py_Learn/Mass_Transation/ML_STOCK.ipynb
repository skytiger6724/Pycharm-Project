# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from sklearn import cluster, covariance, manifold
import yfinance as yf

# Jupyter Notebook显示图形专用
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# Load ETF50 stock IDs
etf50_df = pd.read_csv("ETF50.csv")
etf50_id = etf50_df.loc[:, "STOCK_ID"].astype(str)
frames = []
# Convert STOCK_ID and STOCK_NAME columns to numpy arrays
codes = np.array(etf50_df.loc[:, "STOCK_ID"].astype(str))
names = np.array(etf50_df.loc[:, "STOCK_NAME"].astype(str))
# 获取股票数据并返回DataFrame
def get_data(code, start='2020-01-01', end=None):
    ticker = f"{code}.TW"
    df = yf.download(ticker, start=start, end=end)
    
    if not df.empty:
        # Calculate Trading_money
        df['Trading_money'] = df['Close'] * df['Volume']
        # Add the stock ID to the dataframe
        df['STOCK_ID'] = code
        return df
    else:
        return None

# 获取每个股票的开盘价和收盘价差值，并将其存储在DataFrame中
data = pd.DataFrame({name: get_data(code).Close - get_data(code).Open 
                     for code, name in zip(codes, names) if get_data(code) is not None})

# 检查结果
print(data.head())

# 调用函数获取数据
get_data(etf50_id)

# 检查frames是否为空
if frames:
    # Concatenate all dataframes
    result_df = pd.concat(frames)
    result_df = result_df.reset_index()
    print(result_df.head())
else:
    print("No data to concatenate")



# 获取每个股票的开盘价和收盘价差值
data = pd.DataFrame({name: (get_data(code).Close - get_data(code).Open) for code, name in zip(codes, names)})

# 去除缺失值
variation = data.dropna().values

# 打印数据
#print(data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# 相關係數
edge_model= covariance.GraphicalLassoCV()
X = variation.copy()
X /= X.std(axis=0)
edge_model.fit(X)
_, labels = cluster.affinity_propagation(edge_model.covariance_)
n_labels = labels.max()
for i in range(n_labels + 1):
    print('Cluster %i: %s' % ((i + 1), ', '.join(names[labels == i])))
# Out:
# Cluster 1: 台積電, 鴻海, 聯發科, 台達電, 聯電, 日月光投控
# Cluster 2: 富邦金, 國泰金, 元大金, 中鋼, 開發金, 長榮, 中租-KY
# Cluster 3: 中信金, 兆豐金, 玉山金, 第一金, 永豐金, 合庫金, 華南金, 台新金, 上海商銀
# Cluster 4: 國巨, 大立光, 南亞科
# Cluster 5: 廣達, 華碩, 緯創, 和碩, 光寶科, 世芯-KY, 奇鋐, 緯穎
# Cluster 6: 聯詠, 智邦, 瑞昱, 欣興
# Cluster 7: 統一, 南亞, 台泥, 台塑, 和泰車, 台化, 研華, 台塑化
# Cluster 8: 中華電, 統一超, 台灣大, 遠傳
# Cluster 9: 亞德客-KY
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
node_position_model = manifold.LocallyLinearEmbedding(
    n_components=2, eigen_solver='dense', n_neighbors=6)

embedding = node_position_model.fit_transform(X.T).T

# 可视化
plt.figure(1, facecolor='w', figsize=(10, 8))
plt.clf()
ax = plt.axes([0., 0., 1., 1.])
plt.axis('off')

# 计算偏相关系数
partial_correlations = edge_model.precision_.copy()
d = 1 / np.sqrt(np.diag(partial_correlations))
partial_correlations *= d
partial_correlations *= d[:, np.newaxis]
non_zero = (np.abs(np.triu(partial_correlations, k=1)) > 0.02)

# 使用嵌入的坐标绘制节点
plt.scatter(embedding[0], embedding[1], s=100 * d ** 2, c=labels,
            cmap=plt.cm.nipy_spectral)

# 画相互关联的边
start_idx, end_idx = np.where(non_zero)
segments = [[embedding[:, start], embedding[:, stop]]
            for start, stop in zip(start_idx, end_idx)]
values = np.abs(partial_correlations[non_zero])
lc = LineCollection(segments,
                    zorder=0, cmap=plt.cm.hot_r,
                    norm=plt.Normalize(0, .7 * values.max()))
lc.set_array(values)
lc.set_linewidths(15 * values)
ax.add_collection(lc)

#向每个节点添加一个标签，难点在于定位标签，以避免与其他标签重叠
for index, (name, label, (x, y)) in enumerate(
        zip(names, labels, embedding.T)):

    dx = x - embedding[0]
    dx[index] = 1
    dy = y - embedding[1]
    dy[index] = 1
    this_dx = dx[np.argmin(np.abs(dy))]
    this_dy = dy[np.argmin(np.abs(dx))]
    if this_dx > 0:
        horizontalalignment = 'left'
        x = x + .002
    else:
        horizontalalignment = 'right'
        x = x - .002
    if this_dy > 0:
        verticalalignment = 'bottom'
        y = y + .002
    else:
        verticalalignment = 'top'
        y = y - .002
    plt.text(x, y, name, size=10,
             horizontalalignment=horizontalalignment,
             verticalalignment=verticalalignment,
             bbox=dict(facecolor='w',
                       edgecolor=plt.cm.nipy_spectral(label / float(n_labels)),
                       alpha=.6))

plt.xlim(embedding[0].min() - .15 * embedding[0].ptp(),
         embedding[0].max() + .10 * embedding[0].ptp(),)
plt.ylim(embedding[1].min() - .03 * embedding[1].ptp(),
         embedding[1].max() + .03 * embedding[1].ptp())

plt.show()
